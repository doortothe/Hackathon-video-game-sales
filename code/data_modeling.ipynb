# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split, GridSearchCV, KFold
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.preprocessing import StandardScaler, PolynomialFeatures, FunctionTransformer, OneHotEncoder
from sklearn.linear_model import LinearRegression, Lasso

# %%
df = pd.read_csv('../data/cleaned_video_game_sales.csv', parse_dates=['release_year'])

# %%
df.head()
# Out:
#                        name platform release_year         genre publisher  \
# 0                Wii Sports      Wii   2006-01-01        Sports  Nintendo
# 1         Super Mario Bros.      NES   1985-01-01      Platform  Nintendo
# 2            Mario Kart Wii      Wii   2008-01-01        Racing  Nintendo
# 3         Wii Sports Resort      Wii   2009-01-01        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB   1996-01-01  Role-Playing  Nintendo
#
#    na_sales  eu_sales  jp_sales  other_sales  global_sales  critic_score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    critic_count  user_score  user_count developer rating
# 0          51.0         8.0       322.0  Nintendo      E
# 1           NaN         NaN         NaN       NaN    NaN
# 2          73.0         8.3       709.0  Nintendo      E
# 3          73.0         8.0       192.0  Nintendo      E
# 4           NaN         NaN         NaN       NaN    NaN

# %%
df.rating.value_counts()
# Out:
# E       3991
# T       2961
# M       1563
# E10+    1420
# EC         8
# K-A        3
# RP         3
# AO         1
# Name: rating, dtype: int64

# %%
df.publisher.value_counts().describe()
# Out:
# count     581.000000
# mean       28.683305
# std       116.813038
# min         1.000000
# 25%         1.000000
# 50%         3.000000
# 75%        10.000000
# max      1356.000000
# Name: publisher, dtype: float64

# %%
# No choice but to drop nulls
df.dropna(inplace=True)

# %% [markdown]
# Create squared and interaction features

# %%
# Adjust user_score so it is in the same units as critic score
df.user_score = df.user_score * 10

# %%
poly_features = ['na_sales', 'eu_sales', 'jp_sales', 'other_sales', 'global_sales', \
            'critic_score', 'critic_count', 'user_score', 'user_count']

categorical_features = ['platform', 'genre', 'rating']

get_poly_data = FunctionTransformer(lambda x: x[poly_features], validate=False)
get_cate_data = FunctionTransformer(lambda x: x[categorical_features], validate=False)

# %%
# Convert categorical feature columns into categorical data type
df.platform = df.platform.astype('category')
df.genre = df.genre.astype('category')
df.rating = df.rating.astype('category')

# %%
pipe_poly = Pipeline([
    ('features', FeatureUnion([
        ('poly_features', Pipeline([
            ('selector', get_poly_data),
            ('poly', PolynomialFeatures())
        ])),
        ('cate_features', Pipeline([
            ('selector', get_cate_data),
            ('cate', OneHotEncoder(handle_unknown='ignore'))
        ]))
    ])),
    ('lasso', Lasso())
])

params = {
    'features__poly_features__poly__interaction_only': [False, True],
    'lasso__alpha': [1, 5, 10],
    'lasso__max_iter': [4000, 5000]
}

# %%
X = df[poly_features + categorical_features]
y = df['global_sales']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
gs = GridSearchCV(pipe_poly, params, cv=KFold(5, shuffle=True))
gs.fit(X_train, y_train)
gs.score(X_train, y_train)
# Out:
# 0.9918427925482408

# %%
gs.best_params_
# Out:
# {'features__poly_features__poly__interaction_only': False,
#  'lasso__alpha': 1,
#  'lasso__max_iter': 4000}

# %% [markdown]
# Use LASSO to narrow out which of these new features are noise

# %%
coeffs = gs.best_estimator_.named_steps['lasso'].coef_

# %%
gs.best_estimator_.named_steps['features'].transformer_list[0][1].named_steps['poly'].get_feature_names()
# Out:
# ['1',
#  'x0',
#  'x1',
#  'x2',
#  'x3',
#  'x4',
#  'x5',
#  'x6',
#  'x7',
#  'x8',
#  'x0^2',
#  'x0 x1',
#  'x0 x2',
#  'x0 x3',
#  'x0 x4',
#  'x0 x5',
#  'x0 x6',
#  'x0 x7',
#  'x0 x8',
#  'x1^2',
#  'x1 x2',
#  'x1 x3',
#  'x1 x4',
#  'x1 x5',
#  'x1 x6',
#  'x1 x7',
#  'x1 x8',
#  'x2^2',
#  'x2 x3',
#  'x2 x4',
#  'x2 x5',
#  'x2 x6',
#  'x2 x7',
#  'x2 x8',
#  'x3^2',
#  'x3 x4',
#  'x3 x5',
#  'x3 x6',
#  'x3 x7',
#  'x3 x8',
#  'x4^2',
#  'x4 x5',
#  'x4 x6',
#  'x4 x7',
#  'x4 x8',
#  'x5^2',
#  'x5 x6',
#  'x5 x7',
#  'x5 x8',
#  'x6^2',
#  'x6 x7',
#  'x6 x8',
#  'x7^2',
#  'x7 x8',
#  'x8^2']

# %%
len(poly_features)
# Out:
# 55

# %%
features = ['na_sales', 'eu_sales', 'jp_sales', 'other_sales', 'global_sales', \
            'critic_score', 'critic_count', 'user_score', 'user_count']

df_poly = df[features]

poly = PolynomialFeatures(include_bias=False)

df_poly = poly.fit_transform(df_poly)

pd.DataFrame(df_poly, columns=poly.get_feature_names(features)).head(1)
# Out:
#    na_sales  eu_sales  jp_sales  other_sales  global_sales  critic_score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
#
#    critic_count  user_score  user_count  na_sales^2  ...  critic_score^2  \
# 0          51.0        80.0       322.0   1710.6496  ...          5776.0
#
#    critic_score critic_count  critic_score user_score  \
# 0                     3876.0                   6080.0
#
#    critic_score user_count  critic_count^2  critic_count user_score  \
# 0                  24472.0          2601.0                   4080.0
#
#    critic_count user_count  user_score^2  user_score user_count  user_count^2
# 0                  16422.0        6400.0                25760.0      103684.0
#
# [1 rows x 54 columns]

# %%
poly.get_feature_names(features)
# Out:
# ['x0_3DS',
#  'x0_DC',
#  'x0_DS',
#  'x0_GBA',
#  'x0_GC',
#  'x0_PC',
#  'x0_PS',
#  'x0_PS2',
#  'x0_PS3',
#  'x0_3DS^2',
#  'x0_3DS x0_DC',
#  'x0_3DS x0_DS',
#  'x0_3DS x0_GBA',
#  'x0_3DS x0_GC',
#  'x0_3DS x0_PC',
#  'x0_3DS x0_PS',
#  'x0_3DS x0_PS2',
#  'x0_3DS x0_PS3',
#  'x0_DC^2',
#  'x0_DC x0_DS',
#  'x0_DC x0_GBA',
#  'x0_DC x0_GC',
#  'x0_DC x0_PC',
#  'x0_DC x0_PS',
#  'x0_DC x0_PS2',
#  'x0_DC x0_PS3',
#  'x0_DS^2',
#  'x0_DS x0_GBA',
#  'x0_DS x0_GC',
#  'x0_DS x0_PC',
#  'x0_DS x0_PS',
#  'x0_DS x0_PS2',
#  'x0_DS x0_PS3',
#  'x0_GBA^2',
#  'x0_GBA x0_GC',
#  'x0_GBA x0_PC',
#  'x0_GBA x0_PS',
#  'x0_GBA x0_PS2',
#  'x0_GBA x0_PS3',
#  'x0_GC^2',
#  'x0_GC x0_PC',
#  'x0_GC x0_PS',
#  'x0_GC x0_PS2',
#  'x0_GC x0_PS3',
#  'x0_PC^2',
#  'x0_PC x0_PS',
#  'x0_PC x0_PS2',
#  'x0_PC x0_PS3',
#  'x0_PS^2',
#  'x0_PS x0_PS2',
#  'x0_PS x0_PS3',
#  'x0_PS2^2',
#  'x0_PS2 x0_PS3',
#  'x0_PS3^2']

# %%
cate_features = gs.best_estimator_.named_steps['features'].transformer_list[1][1].named_steps['cate'].get_feature_names()

# %%
len(poly_features)
# Out:
# 55

# %%
features = list(cate_features) + list(poly_features)

# %%
coef_df = pd.DataFrame({'features': features,
                       'coef': coeffs})

# %%
pd.set_option('display.max_rows', None)
coef_df
# Out:
#            features          coef
# 0            x0_3DS  0.000000e+00
# 1             x0_DC  0.000000e+00
# 2             x0_DS  0.000000e+00
# 3            x0_GBA  0.000000e+00
# 4             x0_GC  0.000000e+00
# 5             x0_PC  0.000000e+00
# 6             x0_PS  0.000000e+00
# 7            x0_PS2  0.000000e+00
# 8            x0_PS3  0.000000e+00
# 9            x0_PS4  3.390521e-04
# 10           x0_PSP  0.000000e+00
# 11           x0_PSV  0.000000e+00
# 12           x0_Wii  0.000000e+00
# 13          x0_WiiU  0.000000e+00
# 14          x0_X360  0.000000e+00
# 15            x0_XB  0.000000e+00
# 16          x0_XOne  0.000000e+00
# 17        x1_Action  0.000000e+00
# 18     x1_Adventure -0.000000e+00
# 19      x1_Fighting  0.000000e+00
# 20          x1_Misc  0.000000e+00
# 21      x1_Platform  0.000000e+00
# 22        x1_Puzzle  0.000000e+00
# 23        x1_Racing  0.000000e+00
# 24  x1_Role-Playing  0.000000e+00
# 25       x1_Shooter  0.000000e+00
# 26    x1_Simulation  1.804313e-05
# 27        x1_Sports -0.000000e+00
# 28      x1_Strategy  0.000000e+00
# 29            x2_AO  0.000000e+00
# 30             x2_E -0.000000e+00
# 31          x2_E10+ -0.000000e+00
# 32           x2_K-A -0.000000e+00
# 33             x2_M -2.744438e-04
# 34             x2_T -0.000000e+00
# 35                1  0.000000e+00
# 36               x0  0.000000e+00
# 37               x1 -0.000000e+00
# 38               x2  0.000000e+00
# 39               x3 -1.517369e-04
# 40               x4  4.801127e-04
# 41               x5  9.098377e-03
# 42               x6  0.000000e+00
# 43               x7  3.435519e-03
# 44               x8 -2.943474e-06
# 45             x0^2 -1.085869e-05
# 46            x0 x1 -0.000000e+00
# 47            x0 x2 -2.742967e-05
# 48            x0 x3 -3.247872e-06
# 49            x0 x4 -0.000000e+00
# 50            x0 x5  2.446591e-06
# 51            x0 x6  6.656161e-07
# 52            x0 x7 -0.000000e+00
# 53            x0 x8 -2.166466e-06
# 54             x1^2  1.495410e-08
# 55            x1 x2 -0.000000e+00
# 56            x1 x3  0.000000e+00
# 57            x1 x4 -0.000000e+00
# 58            x1 x5 -0.000000e+00
# 59            x1 x6 -0.000000e+00
# 60            x1 x7 -0.000000e+00
# 61            x1 x8 -0.000000e+00
# 62             x2^2 -0.000000e+00
# 63            x2 x3  0.000000e+00
# 64            x2 x4  0.000000e+00
# 65            x2 x5 -0.000000e+00
# 66            x2 x6  0.000000e+00
# 67            x2 x7  0.000000e+00
# 68            x2 x8  0.000000e+00
# 69             x3^2 -0.000000e+00
# 70            x3 x4 -0.000000e+00
# 71            x3 x5  0.000000e+00
# 72            x3 x6 -0.000000e+00
# 73            x3 x7 -0.000000e+00
# 74            x3 x8 -0.000000e+00
# 75             x4^2  0.000000e+00
# 76            x4 x5 -0.000000e+00
# 77            x4 x6  0.000000e+00
# 78            x4 x7 -0.000000e+00
# 79            x4 x8  0.000000e+00
# 80             x5^2  0.000000e+00
# 81            x5 x6  0.000000e+00
# 82            x5 x7 -0.000000e+00
# 83            x5 x8 -0.000000e+00
# 84             x6^2 -0.000000e+00
# 85            x6 x7  0.000000e+00
# 86            x6 x8  0.000000e+00
# 87             x7^2 -0.000000e+00
# 88            x7 x8 -0.000000e+00
# 89             x8^2 -0.000000e+00

# %% [markdown]
# ## Sources
# 1. https://medium.com/bigdatarepublic/integrating-pandas-and-scikit-learn-with-pipelines-f70eb6183696
# 2. https://blog.usejournal.com/featureunion-a-time-saver-when-building-a-machine-learning-model-d0ad7a90f215
